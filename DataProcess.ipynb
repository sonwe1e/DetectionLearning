# %%
import os
import cv2
import numpy as np


def generate_bbox(mask_path, image_folder):
    """
    Generates bounding box information from mask images.

    Args:
        mask_path: Path to the folder containing mask images.
        image_folder: Path to the folder containing the corresponding images (optional, for verification).

    Returns:
        A dictionary where keys are image filenames (without extension) and values are lists of bounding boxes.
        Each bounding box is a list [xmin, ymin, xmax, ymax].
        Returns an empty dictionary if no masks are found.
    """

    bbox_data = {}
    for filename in os.listdir(mask_path):
        image_info = {}
        if not filename.endswith(
            (".png", ".jpg", ".jpeg", ".bmp")
        ):  # Add other extensions as needed
            continue

        name_without_ext = os.path.splitext(filename)[0]
        mask = cv2.imread(os.path.join(mask_path, filename), cv2.IMREAD_GRAYSCALE)

        if mask is None:
            print(f"Error reading mask: {filename}")
            continue

        # Find contours in the mask
        contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        bboxes = []
        labels = []
        for contour in contours:
            x, y, w, h = cv2.boundingRect(contour)
            bboxes.append([x, y, x + w, y + h])
            labels.append("lesion")
            

        image_info["image_name"] = filename
        image_info["image_size"] = mask.shape
        image_info["bbox"] = bboxes
        image_info["label"] = labels
        bbox_data[name_without_ext] = image_info

        # Optional: Verify bounding boxes on the image (uncomment for debugging)
        # if image_folder:
        #     image_path = os.path.join(image_folder, name_without_ext + ".jpg") # Adjust extension if needed
        #     if os.path.exists(image_path):
        #         image = cv2.imread(image_path)
        #         for bbox in bboxes:
        #             cv2.rectangle(image, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (0, 255, 0), 2)
        #         cv2.imshow("Image with Bounding Boxes", image)
        #         cv2.waitKey(0)
        #         cv2.destroyAllWindows()

    return bbox_data


# Example usage:
mask_folder = (
    "/media/hdd/sonwe1e/Detection/train/masks"  # Replace with your mask folder path
)
image_folder = "/media/hdd/sonwe1e/Detection/train/images"  # Replace with your image folder path (optional)

bbox_info = generate_bbox(mask_folder, image_folder)


# Print or save the bbox information (example - adapt as needed)
for filename, bboxes in bbox_info.items():
    print(f"Image: {filename}")
    for bbox in bboxes:
        print(f"  Bounding Box: {bbox}")


# You can save this information to a file (e.g., JSON or text file) for later use in your detection pipeline.
import json

with open("bbox_data.json", "w") as f:
    json.dump(bbox_info, f, indent=4)
# Out:
# Image: Imge_00001637
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000165895.20012.0002.11474100368
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00006131
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000126017.20018.0022.08584900328
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000129524.20013.0063.14564600841
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000129530.20013.0047.11133400908
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00010408
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00010935
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000129393.20012.0078.14433800826
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00005321
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00007601
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00011361
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00010914
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127683.20012.0021.10125700235
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009094
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00010887
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000129620.20013.0012.09374900502
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000128870.20018.0015.11250200525
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000129717.20013.0025.09180800258
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00005287
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127271.20012.0022.08540100175
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00002306
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000130089.20013.0021.10392300441
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000128479.20018.0060.09014700538
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00003227
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00010886
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000164274.20012.0030.11501600280
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009233
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00007193
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00010898
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009281
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00010392
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127177.20012.0002.08595600640
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00001063
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127734.20013.0013.10184600309
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000126696.20012.0033.10585500922
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000125579.20013.0027.09004300164
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000128043.20013.0009.10041100264
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000130168.20004.0049.10570100501
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008838
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00007505
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009896
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00002500
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00004815
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008589
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00002321
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00007199
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127036.20018.0033.10141600126
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127739.20018.0006.10211400236
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00010929
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009246
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000125918.20013.0013.09254400235
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00001780
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00003412
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000166537.20012.0007.10390000380
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000123768.20018.0001.12122200166
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009131
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000164606.20012.0030.11412400197
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008346
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009730
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000126610.20004.0030.11095900679
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00003409
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000128038.20018.0027.11195900472
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00005976
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127351.20013.0047.11313700517
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00010879
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000129115.20018.0031.11172800352
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000129648.20018.0021.14491800996
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00005775
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00004232
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000129484.20018.0028.14373900762
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000128038.20018.0026.11195000116
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127855.20018.0029.10373100793_1
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00007196
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00000910
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000155444.20018.0029.08450100176
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00010546
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000130219.20013.0034.10105900541
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00007198
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000166023.20012.0063.15115300694
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008171
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00011066
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000165122.20012.0026.09141800883
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00010729
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127483.20013.0015.09092600708
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00000389
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009169
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00010890
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00002186
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009716
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00006593
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009273
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00002498
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000164801.20018.0043.15410000342
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008989
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008090
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000126801.20004.0037.12421100906
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009244
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000165409.20018.0055.11220600192
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008621
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008682
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008590
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00003363
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00005977
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000165847.20012.0059.10463200033
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127036.20018.0032.10093300024
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00001737
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000165306.20018.0059.10250000049
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00006897
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000137834.20013.0018.15084700873
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00002494
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000126263.20013.0006.12340100392
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00005155
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00002497
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000126483.20012.0031.10364200873
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00011363
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000129648.20018.0022.14492600939
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000128370.20018.0040.11553000958
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008588
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00004281
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127351.20013.0013.11104400388
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00002987
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00004467
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008015
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000125925.20012.0015.10441900814
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009862
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000128243.20013.0042.09273300065
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127271.20012.0026.08552200038
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008646
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008517
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000130160.10004.0009.15431200731
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00003623
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127099.20004.0026.08564500935
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000130200.20012.0029.10465600940
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000165187.20018.0031.09521300410
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008091
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000126529.20018.0000.12091400411
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00011534
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000129115.20018.0034.11175000604
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00002625
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00002314
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000128018.20013.0023.11242700224
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000125918.20013.0019.09281000922
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000129419.20018.0011.14550100816
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00008094
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127616.20013.0032.10435400597
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000165130.20012.0017.10181200812
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00001236
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009574
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00002309
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009215
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00009653
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: Imge_00006674
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000128319.20012.0047.15394600337
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label
# Image: 01.0000000127655.20018.0028.10383100075
#   Bounding Box: image_name
#   Bounding Box: image_size
#   Bounding Box: bbox
#   Bounding Box: label

# %%
import os
import json
from PIL import Image


def yolo_to_bbox_format(yolo_annotations_path, images_path, output_json_path):
    bbox_data = {}

    for label_file in os.listdir(yolo_annotations_path):
        if label_file.endswith(".txt"):
            image_name = label_file.replace(".txt", ".png")
            image_path = os.path.join(images_path, image_name)

            # Get image size dynamically
            with Image.open(image_path) as img:
                width, height = img.size

            # Read YOLO annotation
            with open(os.path.join(yolo_annotations_path, label_file), "r") as file:
                lines = file.readlines()

            bboxes = []
            labels = []

            for line in lines:
                parts = line.strip().split()
                class_id = int(parts[0])
                cx, cy, w, h = map(float, parts[1:])

                # Convert normalized YOLO to absolute coordinates
                x_min = int((cx - w / 2) * width)
                y_min = int((cy - h / 2) * height)
                x_max = int((cx + w / 2) * width)
                y_max = int((cy + h / 2) * height)

                # Append to bounding box and label lists
                bboxes.append([x_min, y_min, x_max, y_max])
                labels.append("line")  # Using "line" as the label

            # Save in the required format
            bbox_data[image_name.split(".")[0]] = {
                "image_name": image_name,
                "image_size": [height, width],
                "bbox": bboxes,
                "label": labels,
            }

    # Write to output JSON
    with open(output_json_path, "w") as outfile:
        json.dump(bbox_data, outfile, indent=4)


# Example usage
yolo_annotations_path = "/media/hdd/sonwe1e/Detection/Data/Line/val/labels"  # Path to the YOLO annotations folder
images_path = "/media/hdd/sonwe1e/Detection/Data/Line/val/images"  # Path to the image folder
output_json_path = "/media/hdd/sonwe1e/Detection/Data/Line/val/bbox_data.json"  # Path to save the converted JSON file
yolo_to_bbox_format(yolo_annotations_path, images_path, output_json_path)
